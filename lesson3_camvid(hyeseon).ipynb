# %% [markdown]
# <a href="https://colab.research.google.com/github/hane94/Machine-Learning-Practice/blob/master/lesson3_camvid(hyeseon).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Image segmentation with CamVid

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from fastai.vision import *
from fastai.callbacks.hooks import *
from fastai.utils.mem import *

# %%
path = untar_data(URLs.CAMVID)
path.ls()
# Out:
# ...
# [PosixPath('/root/.fastai/data/camvid/labels'),
#  PosixPath('/root/.fastai/data/camvid/valid.txt'),
#  PosixPath('/root/.fastai/data/camvid/codes.txt'),
#  PosixPath('/root/.fastai/data/camvid/images')]

# %%
path_lbl = path/'labels'
path_img = path/'images'

# %% [markdown]
# ## Subset classes

# %%
# path = Path('./data/camvid-small')

# def get_y_fn(x): return Path(str(x.parent)+'annot')/x.name

# codes = array(['Sky', 'Building', 'Pole', 'Road', 'Sidewalk', 'Tree',
#     'Sign', 'Fence', 'Car', 'Pedestrian', 'Cyclist', 'Void'])

# src = (SegmentationItemList.from_folder(path)
#        .split_by_folder(valid='val')
#        .label_from_func(get_y_fn, classes=codes))

# bs=8
# data = (src.transform(get_transforms(), tfm_y=True)
#         .databunch(bs=bs)
#         .normalize(imagenet_stats))

# %% [markdown]
# ## Data

# %%
fnames = get_image_files(path_img)
fnames[:3]
# Out:
# [PosixPath('/root/.fastai/data/camvid/images/Seq05VD_f00990.png'),
#  PosixPath('/root/.fastai/data/camvid/images/0016E5_06450.png'),
#  PosixPath('/root/.fastai/data/camvid/images/0016E5_04530.png')]

# %%
lbl_names = get_image_files(path_lbl)
lbl_names[:3]
# Out:
# [PosixPath('/root/.fastai/data/camvid/labels/Seq05VD_f02040_P.png'),
#  PosixPath('/root/.fastai/data/camvid/labels/Seq05VD_f01290_P.png'),
#  PosixPath('/root/.fastai/data/camvid/labels/0001TP_010020_P.png')]

# %%
img_f = fnames[0]
img = open_image(img_f)
img.show(figsize=(5,5))

# %% [markdown]
# 사진의 모든 픽셀마다 분류해야하는 문제가 있음 = segmentation
#
# segmentation model
#
# 모든 픽셀에 label이 있는 파일을 다운받아 사용

# %%
get_y_fn = lambda x: path_lbl/f'{x.stem}_P{x.suffix}'

# %%
mask = open_mask(get_y_fn(img_f))
mask.show(figsize=(5,5), alpha=1)

# %% [markdown]
# 보통 이미지를 열 때 open_image를 사용하지만,  일반적인 이미지가 아니기 때문에 open_mask를 사용(컬러코드)

# %%
src_size = np.array(mask.shape[1:])
src_size,mask.data
# Out:
# (array([720, 960]), tensor([[[26, 26, 26,  ..., 21, 21, 21],
#           [26, 26, 26,  ..., 21, 21, 21],
#           [26, 26, 26,  ..., 21, 21, 21],
#           ...,
#           [19, 19, 19,  ..., 17, 17, 17],
#           [19, 19, 19,  ..., 17, 17, 17],
#           [19, 19, 19,  ..., 17, 17, 17]]]))

# %% [markdown]
# 720*960 - size

# %%
codes = np.loadtxt(path/'codes.txt', dtype=str); codes
# Out:
# array(['Animal', 'Archway', 'Bicyclist', 'Bridge', 'Building', 'Car', 'CartLuggagePram', 'Child', 'Column_Pole',
#        'Fence', 'LaneMkgsDriv', 'LaneMkgsNonDriv', 'Misc_Text', 'MotorcycleScooter', 'OtherMoving', 'ParkingBlock',
#        'Pedestrian', 'Road', 'RoadShoulder', 'Sidewalk', 'SignSymbol', 'Sky', 'SUVPickupTruck', 'TrafficCone',
#        'TrafficLight', 'Train', 'Tree', 'Truck_Bus', 'Tunnel', 'VegetationMisc', 'Void', 'Wall'], dtype='<U17')

# %% [markdown]
# 이미지의 정보를 보면 4,4,4,...4,4,4로 나옴 - array에서 0,1,2,3,4번째는 Building이므로, 빌딩이라는 것을 보여주는 것(각 픽셀이 의미하는 것)

# %% [markdown]
# ## Datasets

# %%
size = src_size//2

free = gpu_mem_get_free_no_cache()
# the max size of bs depends on the available GPU RAM
if free > 8200: bs=8
else:           bs=4
print(f"using bs={bs}, have {free}MB of GPU RAM free")
# Out:
# using bs=8, have 15563MB of GPU RAM free

# %%
src = (SegmentationItemList.from_folder(path_img)
       .split_by_fname_file('../valid.txt')
       .label_from_func(get_y_fn, classes=codes))

# %%
data = (src.transform(get_transforms(), size=size, tfm_y=True) #transform y axis
        .databunch(bs=bs)
        .normalize(imagenet_stats))

# %%
data.show_batch(2, figsize=(10,7))

# %%
data.show_batch(2, figsize=(10,7), ds_type=DatasetType.Valid)

# %% [markdown]
# ## Model

# %%
name2id = {v:k for k,v in enumerate(codes)}
void_code = name2id['Void']

def acc_camvid(input, target):
    target = target.squeeze(1)
    mask = target != void_code
    return (input.argmax(dim=1)[mask]==target[mask]).float().mean()

# %%
metrics=acc_camvid
# metrics=accuracy

# %%
wd=1e-2

# %%
learn = unet_learner(data, models.resnet34, metrics=metrics, wd=wd)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet34-333f7ec4.pth" to /root/.cache/torch/checkpoints/resnet34-333f7ec4.pth
# ...

# %%
lr_find(learn)
learn.recorder.plot()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='2', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/2 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>acc_camvid</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
# ...

# %%
lr=3e-3

# %%
learn.fit_one_cycle(10, slice(lr), pct_start=0.9)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>acc_camvid</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.158428</td>
#       <td>0.811546</td>
#       <td>0.792785</td>
#       <td>01:00</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.862670</td>
#       <td>0.680949</td>
#       <td>0.841537</td>
#       <td>00:56</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.714963</td>
#       <td>0.605228</td>
#       <td>0.845449</td>
#       <td>00:56</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.674775</td>
#       <td>0.502969</td>
#       <td>0.862125</td>
#       <td>00:56</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.624400</td>
#       <td>0.485124</td>
#       <td>0.870104</td>
#       <td>00:55</td>
#     </tr>
#     <tr>
#       <td>5</td>
# ...

# %%
learn.save('stage-1')

# %%
learn.load('stage-1');

# %%
learn.show_results(rows=3, figsize=(8,9))

# %%
learn.unfreeze()

# %%
lrs = slice(lr/400,lr/4)

# %%
learn.fit_one_cycle(12, lrs, pct_start=0.8)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>acc_camvid</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.390636</td>
#       <td>0.338200</td>
#       <td>0.896282</td>
#       <td>00:58</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.378074</td>
#       <td>0.330252</td>
#       <td>0.897955</td>
#       <td>00:57</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.369729</td>
#       <td>0.322237</td>
#       <td>0.901377</td>
#       <td>00:58</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.349500</td>
#       <td>0.301522</td>
#       <td>0.912552</td>
#       <td>00:57</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.340665</td>
#       <td>0.300460</td>
#       <td>0.911940</td>
#       <td>00:58</td>
#     </tr>
#     <tr>
#       <td>5</td>
# ...

# %%
learn.save('stage-2');

# %% [markdown]
# ## Go big

# %% [markdown]
# You may have to restart your kernel and come back to this stage if you run out of memory, and may also need to decrease `bs`.

# %%
learn.destroy()

size = src_size

free = gpu_mem_get_free_no_cache()
# the max size of bs depends on the available GPU RAM
if free > 8200: bs=3
else:           bs=1
print(f"using bs={bs}, have {free}MB of GPU RAM free")
# Out:
# this Learner object self-destroyed - it still exists, but no longer usable
# using bs=3, have 15559MB of GPU RAM free

# %%
data = (src.transform(get_transforms(), size=size, tfm_y=True)
        .databunch(bs=bs)
        .normalize(imagenet_stats))

# %%
learn = unet_learner(data, models.resnet34, metrics=metrics, wd=wd)

# %%
learn.load('stage-2');

# %%
lr_find(learn)
learn.recorder.plot()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>acc_camvid</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
# ...

# %%
lr=1e-3

# %%
learn.fit_one_cycle(10, slice(lr), pct_start=0.8)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>acc_camvid</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.363532</td>
#       <td>0.313159</td>
#       <td>0.914723</td>
#       <td>03:38</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.338428</td>
#       <td>0.285520</td>
#       <td>0.920821</td>
#       <td>03:35</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.319079</td>
#       <td>0.279447</td>
#       <td>0.918562</td>
#       <td>03:35</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.329829</td>
#       <td>0.274449</td>
#       <td>0.927001</td>
#       <td>03:35</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.348397</td>
#       <td>0.335501</td>
#       <td>0.913945</td>
#       <td>03:36</td>
#     </tr>
#     <tr>
#       <td>5</td>
# ...

# %%
learn.save('stage-1-big')

# %%
learn.load('stage-1-big');

# %%
learn.unfreeze()

# %%
lrs = slice(1e-6,lr/10)

# %%
learn.fit_one_cycle(10, lrs)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='8' class='' max='10', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       80.00% [8/10 29:40<07:25]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>acc_camvid</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
# ...

# %%
learn.save('stage-2-big')

# %%
learn.load('stage-2-big');

# %%
learn.show_results(rows=3, figsize=(10,10))

# %% [markdown]
# ## fin
