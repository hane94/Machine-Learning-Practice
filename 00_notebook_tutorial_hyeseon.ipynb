# %% [markdown]
# <a href="https://colab.research.google.com/github/hane94/Machine-Learning-Practice/blob/master/00_notebook_tutorial_hyeseon.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
10%3
# Out:
# 1

# %%
from fastai.vision import *
import matplotlib.pyplot as plt

# %%
from PIL import Image

# %%
a = 1
b = a + 1
c = b + a + 1
d = c + b + a + 3
e = d + a + b + c + 1
a,b,c,d,e
# Out:
# (1, 2, 4, 10, 18)

# %%
plt.plot([a,b,c,d])
plt.show()

# %%
Image.open('/content/drive/My Drive/Colab Notebooks/00_notebook_tutorial/cryingdog.jpg')
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=636x638 at 0x7F04DC29B470>
