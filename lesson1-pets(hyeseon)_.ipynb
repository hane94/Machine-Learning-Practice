# %% [markdown]
# <a href="https://colab.research.google.com/github/hane94/Machine-Learning-Practice/blob/master/lesson1-pets(hyeseon)_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install kaggle

# %%
from googleapiclient.discovery import build
import io, os
from googleapiclient.http import MediaIoBaseDownload
from google.colab import auth

auth.authenticate_user()

drive_service = build('drive', 'v3')
results = drive_service.files().list(
        q="name = 'kaggle.json'", fields="files(id)").execute()
kaggle_api_key = results.get('files', [])

filename = "/content/.kaggle/kaggle.json"
os.makedirs(os.path.dirname(filename), exist_ok=True)

request = drive_service.files().get_media(fileId=kaggle_api_key[0]['id'])
fh = io.FileIO(filename, 'wb')
downloader = MediaIoBaseDownload(fh, request)
done = False
while done is False:
    status, done = downloader.next_chunk()
    print("Download %d%%." % int(status.progress() * 100))
os.chmod(filename, 600)
# Out:
# Download 100%.

# %%
pip install fastai

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from fastai.vision import *
from fastai.metrics import error_rate

# %%
bs = 64
# bs = 16   # uncomment this line if you run out of memory even after clicking Kernel->Restart

# %% [markdown]
# bs : Batch Size / How many images do you train at one time?
# 그래픽 램 용량에 따라 다르게 설정 8gb일 경우 32정도..16gb는 64도 괜찮음

# %% [markdown]
# *GPU/CPU에 딸라서 batch size 변경해야 되는데 신경망이 layers 많으면 batch size도 변경시켜야 될 수도 있음*
#
# *신경망, 데이터 사이즈, 그래픽 램에 딸라서 batch size을 선택함*

# %%
path = untar_data(URLs.PETS); path
# Out:
# ...
# PosixPath('/root/.fastai/data/oxford-iiit-pet')

# %%
path.ls()
# Out:
# [PosixPath('/root/.fastai/data/oxford-iiit-pet/annotations'),
#  PosixPath('/root/.fastai/data/oxford-iiit-pet/images')]

# %%
path_anno = path/'annotations'
path_img = path/'images'

# %%
fnames = get_image_files(path_img)
fnames[:5]
# Out:
# [PosixPath('/root/.fastai/data/oxford-iiit-pet/images/staffordshire_bull_terrier_112.jpg'),
#  PosixPath('/root/.fastai/data/oxford-iiit-pet/images/keeshond_61.jpg'),
#  PosixPath('/root/.fastai/data/oxford-iiit-pet/images/Siamese_77.jpg'),
#  PosixPath('/root/.fastai/data/oxford-iiit-pet/images/leonberger_17.jpg'),
#  PosixPath('/root/.fastai/data/oxford-iiit-pet/images/saint_bernard_193.jpg')]

# %%
np.random.seed(2)
pat = r'/([^/]+)_\d+.jpg$'

# %%
data = ImageDataBunch.from_name_re(path_img, fnames, pat, ds_tfms=get_transforms(), size=224, bs=bs
                                  ).normalize(imagenet_stats)

# %%
data.show_batch(rows=3, figsize=(7,6))

# %%
print(data.classes)
len(data.classes),data.c
# Out:
# ['Abyssinian', 'Bengal', 'Birman', 'Bombay', 'British_Shorthair', 'Egyptian_Mau', 'Maine_Coon', 'Persian', 'Ragdoll', 'Russian_Blue', 'Siamese', 'Sphynx', 'american_bulldog', 'american_pit_bull_terrier', 'basset_hound', 'beagle', 'boxer', 'chihuahua', 'english_cocker_spaniel', 'english_setter', 'german_shorthaired', 'great_pyrenees', 'havanese', 'japanese_chin', 'keeshond', 'leonberger', 'miniature_pinscher', 'newfoundland', 'pomeranian', 'pug', 'saint_bernard', 'samoyed', 'scottish_terrier', 'shiba_inu', 'staffordshire_bull_terrier', 'wheaten_terrier', 'yorkshire_terrier']
# (37, 37)

# %% [markdown]
# len(data.classes),data.c => property called c, number of classes

# %% [markdown]
# # resnet34

# %%
learn = cnn_learner(data, models.resnet34, metrics=error_rate)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet34-333f7ec4.pth" to /root/.cache/torch/checkpoints/resnet34-333f7ec4.pth
# ...

# %% [markdown]
# resnet34 -> pretrained model / fastai resnet34 / resnet50 / Keras
# fastai resnet34 -> Keras보다 빠르고 오류 적음 / resnet34(34layers)

# %%
learn.fit_one_cycle(4)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.281805</td>
#       <td>0.212088</td>
#       <td>0.070365</td>
#       <td>01:29</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.354151</td>
#       <td>0.228031</td>
#       <td>0.079161</td>
#       <td>01:29</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.273731</td>
#       <td>0.211313</td>
#       <td>0.069012</td>
#       <td>01:31</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.199386</td>
#       <td>0.193848</td>
#       <td>0.060217</td>
#       <td>01:29</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# fit_one_cycle(반복횟수) 4번 반복일 경우 오류율6%

# %%
learn.save('stage-1')

# %%
interp = ClassificationInterpretation.from_learner(learn)

losses,idxs = interp.top_losses()

len(data.valid_ds)==len(losses)==len(idxs)
# Out:
# True

# %% [markdown]
# from_learner => factory method

# %%
interp.plot_top_losses(9, figsize=(15,11))

# %% [markdown]
# Abyssinian/Bengal/9.28/0.00 => Prediction/Actual/Loss/Probability of actual class

# %%
doc(interp.plot_top_losses)
# Out:
# <h4 id="_cl_int_plot_top_losses" class="doc_header"><code>_cl_int_plot_top_losses</code><a href="https://github.com/fastai/fastai/blob/master/fastai/vision/learner.py#L163" class="source_link" style="float:right">[source]</a><a class="source_link" data-toggle="collapse" data-target="#_cl_int_plot_top_losses-pytest" style="float:right; padding-right:10px">[test]</a></h4><blockquote><p><code>_cl_int_plot_top_losses</code>(<strong><code>k</code></strong>, <strong><code>largest</code></strong>=<strong><em><code>True</code></em></strong>, <strong><code>figsize</code></strong>=<strong><em><code>(12, 12)</code></em></strong>, <strong><code>heatmap</code></strong>:<code>bool</code>=<strong><em><code>False</code></em></strong>, <strong><code>heatmap_thresh</code></strong>:<code>int</code>=<strong><em><code>16</code></em></strong>, <strong><code>alpha</code></strong>:<code>float</code>=<strong><em><code>0.6</code></em></strong>, <strong><code>cmap</code></strong>:<code>str</code>=<strong><em><
# ...

# %% [markdown]
# plot_top_losses에 대한 문서를 보여주는 것
# Show in docs 가이드 볼 수 있음 [source]클릭하면 소스도 볼 수 있음

# %%
interp.plot_confusion_matrix(figsize=(12,12), dpi=60)

# %% [markdown]
# plot_confusion_matrix
# : 얼마나 많이 그 개(그 견종),혹은 고양이(묘종)으로 예측됐는가 보여주는 것

# %%
interp.most_confused(min_val=2)
# Out:
# [('British_Shorthair', 'Russian_Blue', 5),
#  ('Bengal', 'Egyptian_Mau', 4),
#  ('Ragdoll', 'Birman', 4),
#  ('basset_hound', 'beagle', 4),
#  ('beagle', 'basset_hound', 4),
#  ('miniature_pinscher', 'chihuahua', 4),
#  ('Egyptian_Mau', 'Bengal', 3),
#  ('Siamese', 'Birman', 3),
#  ('miniature_pinscher', 'american_pit_bull_terrier', 3),
#  ('staffordshire_bull_terrier', 'american_bulldog', 3),
#  ('yorkshire_terrier', 'havanese', 3),
#  ('Bengal', 'Abyssinian', 2),
#  ('British_Shorthair', 'Bombay', 2),
#  ('Maine_Coon', 'Ragdoll', 2),
#  ('Russian_Blue', 'British_Shorthair', 2),
#  ('american_bulldog', 'american_pit_bull_terrier', 2),
#  ('american_pit_bull_terrier', 'staffordshire_bull_terrier', 2),
#  ('chihuahua', 'miniature_pinscher', 2),
#  ('leonberger', 'keeshond', 2)]

# %% [markdown]
# most_confused : 가장 혼란을 야기하는 combination을 보여줌

# %%
learn.unfreeze()

# %% [markdown]
# train whole model

# %%
learn.fit_one_cycle(1)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.644425</td>
#       <td>0.323885</td>
#       <td>0.097429</td>
#       <td>01:33</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.load('stage-1');

# %%
learn.lr_find()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='2', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/2 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
# ...

# %%
learn.recorder.plot()

# %%
learn.unfreeze()
learn.fit_one_cycle(2, max_lr=slice(1e-6,1e-4))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.185287</td>
#       <td>0.195459</td>
#       <td>0.064276</td>
#       <td>01:32</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.164056</td>
#       <td>0.186471</td>
#       <td>0.061570</td>
#       <td>01:33</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# slice(1e-6,1e-4) Range of Learning Rate

# %% [markdown]
# # resnet50

# %%
data = ImageDataBunch.from_name_re(path_img, fnames, pat, ds_tfms=get_transforms(),
                                   size=299, bs=bs//2).normalize(imagenet_stats)

# %%
doc(ImageDataBunch.from_name_re)
# Out:
# <h4 id="ImageDataBunch.from_name_re" class="doc_header"><code>from_name_re</code><a href="https://github.com/fastai/fastai/blob/master/fastai/vision/data.py#L149" class="source_link" style="float:right">[source]</a><a class="source_link" data-toggle="collapse" data-target="#ImageDataBunch-from_name_re-pytest" style="float:right; padding-right:10px">[test]</a></h4><blockquote><p><code>from_name_re</code>(<strong><code>path</code></strong>:<code>PathOrStr</code>, <strong><code>fnames</code></strong>:<code>FilePathList</code>, <strong><code>pat</code></strong>:<code>str</code>, <strong><code>valid_pct</code></strong>:<code>float</code>=<strong><em><code>0.2</code></em></strong>, <strong>**<code>kwargs</code></strong>)</p>
# </blockquote>
# ...

# %%
learn = cnn_learner(data, models.resnet50, metrics=error_rate)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-19c8e357.pth" to /root/.cache/torch/checkpoints/resnet50-19c8e357.pth
# ...

# %%
learn.lr_find()
learn.recorder.plot()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
# ...

# %%
learn.fit_one_cycle(8)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.722789</td>
#       <td>0.249977</td>
#       <td>0.083897</td>
#       <td>02:13</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.530936</td>
#       <td>0.286507</td>
#       <td>0.101489</td>
#       <td>02:13</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.369248</td>
#       <td>0.339697</td>
#       <td>0.089986</td>
#       <td>02:13</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.359487</td>
#       <td>0.227014</td>
#       <td>0.069012</td>
#       <td>02:13</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.223356</td>
#       <td>0.197158</td>
#       <td>0.060217</td>
#       <td>02:10</td>
#     </tr>
#     <tr>
#       <td>5</td>
# ...

# %%
learn.save('stage-1-50')

# %%
learn.unfreeze()
learn.fit_one_cycle(3, max_lr=slice(1e-6,1e-4))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.109609</td>
#       <td>0.176262</td>
#       <td>0.052097</td>
#       <td>02:12</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.097523</td>
#       <td>0.166375</td>
#       <td>0.047361</td>
#       <td>02:11</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.087923</td>
#       <td>0.169516</td>
#       <td>0.049391</td>
#       <td>02:08</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.load('stage-1-50');

# %%
interp = ClassificationInterpretation.from_learner(learn)

# %%
interp.most_confused(min_val=2)
# Out:
# [('Ragdoll', 'Birman', 6),
#  ('american_pit_bull_terrier', 'staffordshire_bull_terrier', 6),
#  ('boxer', 'american_bulldog', 4),
#  ('miniature_pinscher', 'chihuahua', 4),
#  ('Egyptian_Mau', 'Bengal', 3),
#  ('yorkshire_terrier', 'havanese', 3),
#  ('Bengal', 'Egyptian_Mau', 2),
#  ('British_Shorthair', 'Russian_Blue', 2),
#  ('Ragdoll', 'Persian', 2),
#  ('Russian_Blue', 'British_Shorthair', 2),
#  ('miniature_pinscher', 'american_pit_bull_terrier', 2),
#  ('staffordshire_bull_terrier', 'american_bulldog', 2)]

# %%
path = untar_data(URLs.MNIST_SAMPLE); path
# Out:
# ...
# PosixPath('/root/.fastai/data/mnist_sample')

# %%
tfms = get_transforms(do_flip=False)
data = ImageDataBunch.from_folder(path, ds_tfms=tfms, size=26)

# %%
data.show_batch(rows=3, figsize=(5,5))

# %%
learn = cnn_learner(data, models.resnet18, metrics=accuracy)
learn.fit(2)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-5c106cde.pth" to /root/.cache/torch/checkpoints/resnet18-5c106cde.pth
# ...
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.198486</td>
#       <td>0.084439</td>
#       <td>0.969087</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.117479</td>
#       <td>0.055652</td>
#       <td>0.982336</td>
#       <td>00:22</td>
#     </tr>
#   </tbody>
# </table>

# %%
df = pd.read_csv(path/'labels.csv')
df.head()
# Out:
#                 name  label
# 0   train/3/7463.png      0
# 1  train/3/21102.png      0
# 2  train/3/31559.png      0
# 3  train/3/46882.png      0
# 4  train/3/26209.png      0

# %%
data = ImageDataBunch.from_csv(path, ds_tfms=tfms, size=28)

# %%
data.show_batch(rows=3, figsize=(5,5))
data.classes
# Out:
# [0, 1]

# %%
data = ImageDataBunch.from_df(path, df, ds_tfms=tfms, size=24)
data.classes
# Out:
# [0, 1]

# %%
fn_paths = [path/name for name in df['name']]; fn_paths[:2]
# Out:
# [PosixPath('/root/.fastai/data/mnist_sample/train/3/7463.png'),
#  PosixPath('/root/.fastai/data/mnist_sample/train/3/21102.png')]

# %%
pat = r"/(\d)/\d+\.png$"
data = ImageDataBunch.from_name_re(path, fn_paths, pat=pat, ds_tfms=tfms, size=24)
data.classes
# Out:
# ['3', '7']

# %%
data = ImageDataBunch.from_name_func(path, fn_paths, ds_tfms=tfms, size=24,
        label_func = lambda x: '3' if '/3/' in str(x) else '7')
data.classes
# Out:
# ['3', '7']

# %%
labels = [('3' if '/3/' in str(x) else '7') for x in fn_paths]
labels[:5]
# Out:
# ['3', '3', '3', '3', '3']

# %%
data = ImageDataBunch.from_lists(path, fn_paths, labels=labels, ds_tfms=tfms, size=24)
data.classes
# Out:
# ['3', '7']
