# %% [markdown]
# <a href="https://colab.research.google.com/github/hane94/Machine-Learning-Practice/blob/master/lesson3_planet(hyeseon).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Multi-label prediction with Planet Amazon dataset

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from fastai.vision import *

# %% [markdown]
# ## Getting the data (Kaggle Data) - 현재 사용 못함

# %% [markdown]
# The planet dataset isn't available on the [fastai dataset page](https://course.fast.ai/datasets) due to copyright restrictions. You can download it from Kaggle however. Let's see how to do this by using the [Kaggle API](https://github.com/Kaggle/kaggle-api) as it's going to be pretty useful to you if you want to join a competition or use other Kaggle datasets later on.
#
# First, install the Kaggle API by uncommenting the following line and executing it, or by executing it in your terminal (depending on your platform you may need to modify this slightly to either add `source activate fastai` or similar, or prefix `pip` with a path. Have a look at how `conda install` is called for your platform in the appropriate *Returning to work* section of https://course.fast.ai/. (Depending on your environment, you may also need to append "--user" to the command.)

# %%
# ! {sys.executable} -m pip install kaggle --upgrade

# %% [markdown]
# 데이터셋 사용을 위한 설정

# %% [markdown]
# Then you need to upload your credentials from Kaggle on your instance. Login to kaggle and click on your profile picture on the top left corner, then 'My account'. Scroll down until you find a button named 'Create New API Token' and click on it. This will trigger the download of a file named 'kaggle.json'.
#
# Upload this file to the directory this notebook is running in, by clicking "Upload" on your main Jupyter page, then uncomment and execute the next two commands (or run them in a terminal). For Windows, uncomment the last two commands.

# %%
# ! mkdir -p ~/.kaggle/
# ! mv kaggle.json ~/.kaggle/

# For Windows, uncomment these two commands
# ! mkdir %userprofile%\.kaggle
# ! move kaggle.json %userprofile%\.kaggle

# %% [markdown]
# You're all set to download the data from [planet competition](https://www.kaggle.com/c/planet-understanding-the-amazon-from-space). You **first need to go to its main page and accept its rules**, and run the two cells below (uncomment the shell commands to download and unzip the data). If you get a `403 forbidden` error it means you haven't accepted the competition rules yet (you have to go to the competition page, click on *Rules* tab, and then scroll to the bottom to find the *accept* button).

# %%
path = Config.data_path()/'planet'
path.mkdir(parents=True, exist_ok=True)
path
# Out:
# PosixPath('/home/ubuntu/.fastai/data/planet')

# %%
# ! kaggle competitions download -c planet-understanding-the-amazon-from-space -f train-jpg.tar.7z -p {path}  
# ! kaggle competitions download -c planet-understanding-the-amazon-from-space -f train_v2.csv -p {path}  
# ! unzip -q -n {path}/train_v2.csv.zip -d {path}

# %% [markdown]
# Kaggle 데이터셋을 API를 이용하여 설치/ 압축풀기

# %% [markdown]
# To extract the content of this file, we'll need 7zip, so uncomment the following line if you need to install it (or run `sudo apt install p7zip-full` in your terminal).

# %%
# ! conda install --yes --prefix {sys.prefix} -c haasad eidl7zip

# %% [markdown]
# And now we can unpack the data (uncomment to run - this might take a few minutes to complete).

# %%
# ! 7za -bd -y -so x {path}/train-jpg.tar.7z | tar xf - -C {path.as_posix()}

# %% [markdown]
# # Google Drive Dataset

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
path = Path('/content/gdrive/My Drive/Colab Notebooks/Lesson3/data/planet')
images = path/'train-jpg'

# %%
path.ls()
# Out:
# [PosixPath('/content/gdrive/My Drive/Colab Notebooks/Lesson3/data/planet/train_v2.csv'),
#  PosixPath('/content/gdrive/My Drive/Colab Notebooks/Lesson3/data/planet/sample_submission_v2.csv'),
#  PosixPath('/content/gdrive/My Drive/Colab Notebooks/Lesson3/data/planet/test_v2_file_mapping.csv'),
#  PosixPath('/content/gdrive/My Drive/Colab Notebooks/Lesson3/data/planet/train-jpg'),
#  PosixPath('/content/gdrive/My Drive/Colab Notebooks/Lesson3/data/planet/train-jpg_1000'),
#  PosixPath('/content/gdrive/My Drive/Colab Notebooks/Lesson3/data/planet/train_v2_Edited.csv'),
#  PosixPath('/content/gdrive/My Drive/Colab Notebooks/Lesson3/data/planet/models')]

# %% [markdown]
# ## Multiclassification

# %% [markdown]
# Contrary to the pets dataset studied in last lesson, here each picture can have multiple labels. If we take a look at the csv file containing the labels (in 'train_v2.csv' here) we see that each 'image_name' is associated to several tags separated by spaces.

# %%
df = pd.read_csv(path/'train_v2_Edited.csv')
df.head()
# Out:
#   image_name                                       tags
# 0    train_0                               haze primary
# 1    train_1            agriculture clear primary water
# 2    train_2                              clear primary
# 3    train_3                              clear primary
# 4    train_4  agriculture clear habitation primary road

# %% [markdown]
# 멀티플 레이블을 폴더를 통해 나눌 수 없기 때문에 Kaggle데이터는 CSV파일을 제공
#
# Pandas 라이브러리를 이용해서 csv파일 읽어오기

# %% [markdown]
# To put this in a `DataBunch` while using the [data block API](https://docs.fast.ai/data_block.html), we then need to using `ImageList` (and not `ImageDataBunch`). This will make sure the model created has the proper loss function to deal with the multiple classes.

# %%
tfms = get_transforms(flip_vert=True, max_lighting=0.1, max_zoom=1.05, max_warp=0.)

# %% [markdown]
# 트랜스폼의 기본 설정값은 랜덤하게 이미지를 뒤집는 것, 항공사진이나 위성사진 등은 이렇게 코드를 짜주는 게...적절한 모델을 만들기에 좋은..?

# %% [markdown]
# *네. transforms을 한 후 model이 학습을 잘 할 수 있다. 동질적 데이터셋을 있으면 학습이 더 쉽다*

# %% [markdown]
# We use parentheses around the data block pipeline below, so that we can use a multiline statement without needing to add '\\'.

# %%
np.random.seed(42)
src = (ImageList.from_csv(path, 'train_v2_Edited.csv', folder='train-jpg_1000', suffix='.jpg')
       .split_by_rand_pct(0.2) #Split the items randomly by putting valid_pct in the validation set, optional
       .label_from_df(label_delim=' '))#creating dataset

# %% [markdown]
# spilt_by_rand_pct
#
# Split the items randomly by putting valid_pct in the validation set, optional seed can be passed.
#
# ImageList : Used to grab the planet data
#
# path, csv파일(레이블),폴더,
#
# 위의 코드는 순서에 맞게 사용해야함

# %%
data = (src.transform(tfms, size=128)
        .databunch().normalize(imagenet_stats))

# %% [markdown]
# 데이터 로더와 데이터 번치를 한번에 형성할 수 있는 코드

# %% [markdown]
# dataset class : part of pytorch
#
# define two things
#
# __getitem__
# : 오브젝트 인덱싱 ex)오브젝트 O -> O[3] What is thrid item of data in my dataset?
#
# __len__ : how big is the dataset?
#
#
#
# ---
# databunch class : bind together a train_dl,valid_dl

# %% [markdown]
# `show_batch` still works, and show us the different labels separated by `;`.

# %%
data.show_batch(rows=3, figsize=(12,9))

# %% [markdown]
# To create a `Learner` we use the same function as in lesson 1. Our base architecture is resnet50 again, but the metrics are a little bit differeent: we use `accuracy_thresh` instead of `accuracy`. In lesson 1, we determined the predicition for a given class by picking the final activation that was the biggest, but here, each activation can be 0. or 1. `accuracy_thresh` selects the ones that are above a certain threshold (0.5 by default) and compares them to the ground truth.
#
# As for Fbeta, it's the metric that was used by Kaggle on this competition. See [here](https://en.wikipedia.org/wiki/F1_score) for more details.

# %%
arch = models.resnet50

# %%
acc_02 = partial(accuracy_thresh, thresh=0.2)
f_score = partial(fbeta, thresh=0.2)
learn = cnn_learner(data, arch, metrics=[acc_02, f_score])
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-19c8e357.pth" to /root/.cache/torch/checkpoints/resnet50-19c8e357.pth
# HBox(children=(IntProgress(value=0, max=102502400), HTML(value='')))

# %%
data.classes
# Out:
# ['agriculture',
#  'artisinal_mine',
#  'bare_ground',
#  'blooming',
#  'blow_down',
#  'clear',
#  'cloudy',
#  'conventional_mine',
#  'cultivation',
#  'habitation',
#  'haze',
#  'partly_cloudy',
#  'primary',
#  'road',
#  'selective_logging',
#  'slash_burn',
#  'water']

# %% [markdown]
# metric -> 이 값을 바꿔도 트레이닝에 영향을 주지않음, 트레이닝하는 동안 프린트되는 값을 위해 변경(fbeta)
# 여기서는 정확도(accuracy),하나는 캐글과 관련된 수치를 보기 위해 사용
#
# data.classes => 17가지 가능성

# %% [markdown]
# We use the LR Finder to pick a good learning rate.

# %%
learn.lr_find()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='7' class='' max='9', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       77.78% [7/9 03:20<00:57]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy_thresh</th>
#       <th>fbeta</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.047655</td>
#       <td>#na#</td>
#       <td>02:40</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.040235</td>
#       <td>#na#</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.036068</td>
#       <td>#na#</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.008021</td>
#       <td>#na#</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.951334</td>
#       <td>#na#</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.818420</td>
#       <td>#na#</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.735798</td>
#       <td>#na#</td>
#       <td>00:05</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='8' class='' max='12', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       66.67% [8/12 00:04<00:02 2.3208]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %% [markdown]
# Then we can fit the head of our network.

# %%
lr = 0.01

# %%
learn.fit_one_cycle(5, slice(lr))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy_thresh</th>
#       <th>fbeta</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.899709</td>
#       <td>0.791593</td>
#       <td>0.389299</td>
#       <td>0.509934</td>
#       <td>01:21</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.704722</td>
#       <td>0.329883</td>
#       <td>0.769140</td>
#       <td>0.730418</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.499491</td>
#       <td>0.184255</td>
#       <td>0.929057</td>
#       <td>0.860395</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.382181</td>
#       <td>0.163286</td>
#       <td>0.929353</td>
#       <td>0.870197</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.310481</td>
#       <td>0.159769</td>
#       <td>0.930239</td>
#       <td>0.868215</td>
#       <td>00:06</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('stage-1-rn50') #save model

# %% [markdown]
# ...And fine-tune the whole model:

# %%
learn.unfreeze()

# %%
learn.lr_find()
learn.recorder.plot()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='7' class='' max='9', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       77.78% [7/9 00:47<00:13]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy_thresh</th>
#       <th>fbeta</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.145698</td>
#       <td>#na#</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.150379</td>
#       <td>#na#</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.147571</td>
#       <td>#na#</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.139417</td>
#       <td>#na#</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.148415</td>
#       <td>#na#</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.179192</td>
#       <td>#na#</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.287338</td>
#       <td>#na#</td>
#       <td>00:06</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='3' class='' max='12', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       25.00% [3/12 00:02<00:06 0.4442]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.fit_one_cycle(5, slice(1e-5, lr/5))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy_thresh</th>
#       <th>fbeta</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.139590</td>
#       <td>0.163623</td>
#       <td>0.935560</td>
#       <td>0.870679</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.136130</td>
#       <td>0.167550</td>
#       <td>0.938516</td>
#       <td>0.875516</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.129337</td>
#       <td>0.158253</td>
#       <td>0.942359</td>
#       <td>0.874269</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.119117</td>
#       <td>0.146865</td>
#       <td>0.942359</td>
#       <td>0.880871</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.110060</td>
#       <td>0.143256</td>
#       <td>0.945315</td>
#       <td>0.887002</td>
#       <td>00:07</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('stage-2-rn50')

# %%
data = (src.transform(tfms, size=256)
        .databunch().normalize(imagenet_stats))

learn.data = data
data.train_ds[0][0].shape
# Out:
# torch.Size([3, 256, 256])

# %% [markdown]
# 캐글이미지는 256사이즈, 128로 하면 더 빨리할 수 있음
#
# 256으로 한 것은 완전히 다른 데이터셋으로 간주
#
# 256사이즈로 새롭게 데이터셋 형성

# %%
learn.freeze()

# %%
learn.lr_find()
learn.recorder.plot()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='7' class='' max='9', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       77.78% [7/9 01:53<00:32]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy_thresh</th>
#       <th>fbeta</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.128719</td>
#       <td>#na#</td>
#       <td>00:22</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.122570</td>
#       <td>#na#</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.123958</td>
#       <td>#na#</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.121881</td>
#       <td>#na#</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.119189</td>
#       <td>#na#</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.127303</td>
#       <td>#na#</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.255602</td>
#       <td>#na#</td>
#       <td>00:15</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='3' class='' max='12', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       25.00% [3/12 00:04<00:13 0.4114]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
lr=1e-2/2

# %%
learn.fit_one_cycle(5, slice(lr))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy_thresh</th>
#       <th>fbeta</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.123972</td>
#       <td>0.141718</td>
#       <td>0.942654</td>
#       <td>0.868013</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.118881</td>
#       <td>0.146552</td>
#       <td>0.942950</td>
#       <td>0.880973</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.112331</td>
#       <td>0.147549</td>
#       <td>0.945610</td>
#       <td>0.894272</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.105540</td>
#       <td>0.147826</td>
#       <td>0.941768</td>
#       <td>0.885607</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.099514</td>
#       <td>0.143160</td>
#       <td>0.943246</td>
#       <td>0.885888</td>
#       <td>00:17</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('stage-1-256-rn50')

# %%
learn.unfreeze()

# %%
learn.fit_one_cycle(5, slice(1e-5, lr/5))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy_thresh</th>
#       <th>fbeta</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.064893</td>
#       <td>0.141112</td>
#       <td>0.943541</td>
#       <td>0.888736</td>
#       <td>00:22</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.063551</td>
#       <td>0.157773</td>
#       <td>0.949749</td>
#       <td>0.895245</td>
#       <td>00:22</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.061990</td>
#       <td>0.162220</td>
#       <td>0.945019</td>
#       <td>0.885432</td>
#       <td>00:22</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.058728</td>
#       <td>0.147060</td>
#       <td>0.949453</td>
#       <td>0.895323</td>
#       <td>00:22</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.054917</td>
#       <td>0.143854</td>
#       <td>0.948862</td>
#       <td>0.895201</td>
#       <td>00:22</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.recorder.plot_losses()

# %%
learn.save('stage-2-256-rn50')

# %% [markdown]
# You won't really know how you're going until you submit to Kaggle, since the leaderboard isn't using the same subset as we have for training. But as a guide, 50th place (out of 938 teams) on the private leaderboard was a score of `0.930`.

# %%
learn.export()

# %% [markdown]
# ## fin

# %% [markdown]
# (This section will be covered in part 2 - please don't ask about it just yet! :) )

# %%
#! kaggle competitions download -c planet-understanding-the-amazon-from-space -f test-jpg.tar.7z -p {path}  
#! 7za -bd -y -so x {path}/test-jpg.tar.7z | tar xf - -C {path}
#! kaggle competitions download -c planet-understanding-the-amazon-from-space -f test-jpg-additional.tar.7z -p {path}  
#! 7za -bd -y -so x {path}/test-jpg-additional.tar.7z | tar xf - -C {path}

# %%
test = ImageList.from_folder(path/'test-jpg').add(ImageList.from_folder(path/'test-jpg-additional'))
len(test)
# Out:
# 61191

# %%
learn = load_learner(path, test=test)
preds, _ = learn.get_preds(ds_type=DatasetType.Test)

# %%
thresh = 0.2
labelled_preds = [' '.join([learn.data.classes[i] for i,p in enumerate(pred) if p > thresh]) for pred in preds]

# %%
labelled_preds[:5]
# Out:
# ['agriculture cultivation partly_cloudy primary road',
#  'clear haze primary water',
#  'agriculture clear cultivation primary',
#  'clear primary',
#  'partly_cloudy primary']

# %%
fnames = [f.name[:-4] for f in learn.data.test_ds.items]

# %%
df = pd.DataFrame({'image_name':fnames, 'tags':labelled_preds}, columns=['image_name', 'tags'])

# %%
df.to_csv(path/'submission.csv', index=False)

# %%
! kaggle competitions submit planet-understanding-the-amazon-from-space -f {path/'submission.csv'} -m "My submission"
# Out:
# Warning: Your Kaggle API key is readable by other users on this system! To fix this, you can run 'chmod 600 /home/ubuntu/.kaggle/kaggle.json'
# 100%|██████████████████████████████████████| 2.18M/2.18M [00:02<00:00, 1.05MB/s]
# Successfully submitted to Planet: Understanding the Amazon from Space

# %% [markdown]
# Private Leaderboard score: 0.9296 (around 80th)
